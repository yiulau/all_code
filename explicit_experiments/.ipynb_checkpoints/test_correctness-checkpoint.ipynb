# %%
# %run -i "new_testleapfrog_logit.py"
# Out:
# /home/yiulau/miniconda2/envs/py36/lib/python3.6/site-packages/pystan/misc.py:399: FutureWarning: Conversion of the second argument of issubdtype from `float` to `np.floating` is deprecated. In future, it will be treated as `np.float64 == np.dtype(float).type`.
#   elif np.issubdtype(np.asarray(v).dtype, float):
# round 0
# current_H 676.8552856445312,propsed_H603.2498779296875
# accept_rate 1.0
# round 1
# current_H 425.57550048828125,propsed_H406.3403625488281
# accept_rate 1.0
# round 2
# current_H 336.7567138671875,propsed_H331.152099609375
# accept_rate 1.0
# round 3
# current_H 299.53350830078125,propsed_H296.220947265625
# accept_rate 1.0
# round 4
# current_H 285.21502685546875,propsed_H284.29150390625
# accept_rate 1.0
# round 5
# current_H 283.0634765625,propsed_H282.4505920410156
# accept_rate 1.0
# round 6
# current_H 281.8948669433594,propsed_H282.10760498046875
# accept_rate 0.8083678718663696
# round 7
# current_H 279.1062927246094,propsed_H278.0528869628906
# ...
